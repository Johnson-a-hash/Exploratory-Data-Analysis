# %% [markdown]
# # EXPLORATORY DATA ANALYSIS USING PYTHON
# ##### By Alberta A. Johnson

# %% [markdown]
# ### SOME INFORMATION ABOUT THE DATASET
#
# This Data Set is about less endowed students(High School students in the deprived communities).
# This program was introduced by the Kwame Nkrumah University of Science and Technology.
# The data was extracted from the KNUST official website.
#
# NB: THE DATA IS USED STRICTLY FOR EDUCATIONAL PURPOSES

# %% [markdown]
# # Importing the necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook
import seaborn as sns
import dataframe_image as dfi

# %% [markdown]
# ### Load the Dataset

# %%
knust = pd.read_csv(r"C:\Users\Alberta\Desktop\Data Science Class\DataInsight\Data-Analysis-and-Visualization-main\EDA of KNUST less endowed students Dataset\knust_stu.csv")
knust
# Out:
#       Unnamed: 0     #                          Full Name  \
# 0              0     1               APPIAH, KELVIN (Mr.)
# 1              1     2            BAAFI, FRANCISCA (Miss)
# 2              2     3              DUODUWAA, ROSE (Miss)
# 3              3     4    DZRAMADO, KENNEDY SOLOMON (Mr.)
# 4              4     5                 OSEI, THOMAS (Mr.)
# ...          ...   ...                                ...
# 1495        1495  1496  ACKAAH-BOATENG, EMMANUELLA (Miss)
# 1496        1496  1497        AGYAPONG, DUKU JOSEPH (Mr.)
# 1497        1497  1498             AKORNOR, CLEMENT (Mr.)
# 1498        1498  1499            AMPONSAH, MICHAEL (Mr.)
# 1499        1499  1500                DANSO, GIDEON (Mr.)
#
#                                     Programme                        School  \
# 0                        BSC. MECHANICAL ENG.    ACHINAKROM SNR HIGH SCHOOL
# 1              BSC. CONSTRUCTION TECH. & MGT.    ACHINAKROM SNR HIGH SCHOOL
# 2     BSC. HOSPITALITY AND TOURISM MANAGEMENT    ACHINAKROM SNR HIGH SCHOOL
# 3                 BSC. HUMAN BIOLOGY, MB.CH.B    ACHINAKROM SNR HIGH SCHOOL
# 4                               BA. ECONOMICS    ACHINAKROM SNR HIGH SCHOOL
# ...                                       ...                           ...
# 1495         BSC. FOOD SCIENCE AND TECHNOLOGY  SEFWI BEKWAI SNR HIGH SCHOOL
# 1496                            BA. ECONOMICS  SEFWI BEKWAI SNR HIGH SCHOOL
# 1497                       BSC. CHEMICAL ENG.  SEFWI BEKWAI SNR HIGH SCHOOL
# 1498                 BSC. BIOLOGICAL SCIENCES  SEFWI BEKWAI SNR HIGH SCHOOL
# 1499                        BSC. BIOCHEMISTRY  SEFWI BEKWAI SNR HIGH SCHOOL
#
#        Region
# 0     ASHANTI
# 1     ASHANTI
# 2     ASHANTI
# 3     ASHANTI
# 4     ASHANTI
# ...       ...
# 1495  WESTERN
# 1496  WESTERN
# 1497  WESTERN
# 1498  WESTERN
# 1499  WESTERN
#
# [1500 rows x 6 columns]

# %%
knust.head()
# Out:
#    Unnamed: 0  #                        Full Name  \
# 0           0  1             APPIAH, KELVIN (Mr.)
# 1           1  2          BAAFI, FRANCISCA (Miss)
# 2           2  3            DUODUWAA, ROSE (Miss)
# 3           3  4  DZRAMADO, KENNEDY SOLOMON (Mr.)
# 4           4  5               OSEI, THOMAS (Mr.)
#
#                                  Programme                      School  \
# 0                     BSC. MECHANICAL ENG.  ACHINAKROM SNR HIGH SCHOOL
# 1           BSC. CONSTRUCTION TECH. & MGT.  ACHINAKROM SNR HIGH SCHOOL
# 2  BSC. HOSPITALITY AND TOURISM MANAGEMENT  ACHINAKROM SNR HIGH SCHOOL
# 3              BSC. HUMAN BIOLOGY, MB.CH.B  ACHINAKROM SNR HIGH SCHOOL
# 4                            BA. ECONOMICS  ACHINAKROM SNR HIGH SCHOOL
#
#     Region
# 0  ASHANTI
# 1  ASHANTI
# 2  ASHANTI
# 3  ASHANTI
# 4  ASHANTI

# %%
knust2 = knust.head()
knust2
dfi.export(knust2, r"C:\Users\Alberta\Desktop\Data Science Class\DataInsight\alberta-main\knust2.png")

# %% [markdown]
# ## Cleaning the Dataset

# %%
knust.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1500 non-null   int64
#  1   #           1500 non-null   int64
#  2   Full Name   1500 non-null   object
#  3   Programme   1500 non-null   object
#  4   School      1500 non-null   object
#  5   Region      1500 non-null   object
# dtypes: int64(2), object(4)
# memory usage: 70.4+ KB

# %%
# The above data contains two irrelevant datasets, the first two columns.
# It doesn't really contribute to the goal of this project, it is just number of entries being listed. We can safely drop
# it

knust.drop(['Unnamed: 0','#'],axis=1,inplace=True)

# %%
knust.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Full Name  1500 non-null   object
#  1   Programme  1500 non-null   object
#  2   School     1500 non-null   object
#  3   Region     1500 non-null   object
# dtypes: object(4)
# memory usage: 47.0+ KB

# %%
knust.describe()
# Out:
#                                Full Name    Programme  \
# count                               1500         1500
# unique                              1484           78
# top     NLANSONG, NJIBICHE FRANCIS (Mr.)  BA. HISTORY
# freq                                   2           97
#
#                              School   Region
# count                          1500     1500
# unique                          277       10
# top     SEKYEDUMASE SNR HIGH SCHOOL  EASTERN
# freq                             11      250

# %%
knust.isnull().sum()
# Out:
# Full Name    0
# Programme    0
# School       0
# Region       0
# dtype: int64

# %%
# lets make a copy of the actual data set into dataframe
df = knust.copy()

# %%
df.sample(5)
# Out:
#                          Full Name  \
# 320           DARKO, BANABAS (Mr.)
# 616              ASMAH, SETH (Mr.)
# 278            ASANTE, MARET (Mr.)
# 1346         AMADU, MOHAMMED (Mr.)
# 1138  BORGSOR, NAAB EMMANUEL (Mr.)
#
#                                               Programme  \
# 320                             BA. CULTURE AND TOURISM
# 616                            BSC. BIOLOGICAL SCIENCES
# 278                 BA. GEOGRAPHY AND RURAL DEVELOPMENT
# 1346  BSC. METALSMITHING AND JEWELLERY TECHNOLOGY (I...
# 1138                              BA. POLITICAL STUDIES
#
#                              School       Region
# 320   GYAMFI KUMANINI SNR HIGH TECH  BRONG AHAFO
# 616     MANDO SNR HIGH TECH. SCHOOL      CENTRAL
# 278     BOMAA COMMUNITY/SEC. SCHOOL  BRONG AHAFO
# 1346   TSITO SNR. HIGH/TECH. SCHOOL        VOLTA
# 1138             KO SNR HIGH SCHOOL   UPPER WEST

# %%
# We are now going to group each student according to gender.
# This can be done by using the 'Miss' and 'Mr' which is at the end of every name
x = df['Full Name'].str[-6:].str.strip().value_counts()
y = df['Full Name'].str[-6:].str.strip().value_counts(normalize=True)
print(x)
print(y)
# Out:
# (Mr.)     824
# (Miss)    676
# Name: Full Name, dtype: int64
# (Mr.)     0.549333
# (Miss)    0.450667
# Name: Full Name, dtype: float64

# %%
print(x)
print(y*100)
# Out:
# (Mr.)     824
# (Miss)    676
# Name: Full Name, dtype: int64
# (Mr.)     54.933333
# (Miss)    45.066667
# Name: Full Name, dtype: float64

# %% [markdown]
# ## DATA VISUALIZATION

# %% [markdown]
# #### Now let us take a look at the number of regions which participated in the program and the percentage of students number in each region

# %%
region_name  = df['Region'].value_counts().index
region_stu_num = df['Region'].value_counts().values
region_name
# Out:
# Index(['EASTERN', 'BRONG AHAFO', 'ASHANTI', 'CENTRAL', 'VOLTA', 'WESTERN',
#        'NORTHERN', 'UPPER WEST', 'UPPER EAST', 'GREATER ACCRA'],
#       dtype='object')

# %%
region_stu_num
# Out:
# array([250, 240, 238, 216, 204, 122,  83,  55,  49,  43], dtype=int64)

# %%
### Lets check the regions which participated in the program
fig,ax = plt.subplots()
# This is to explode the region with most number of students
explode=[0]*len(region_name)
explode[0]=0.1
ax.pie(region_stu_num,labels=region_name,autopct='%1.2f%%',shadow=True,explode=explode,radius=1);
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
region = (df['Region'].value_counts(normalize=True)*100)
print('{} region has the largest number of students  with a percentage of {}%'.format(region.idxmax(),np.round(region.max(),2)))
print('{} region has the least number of students  with a percentage of {}%'.format(region.idxmin(),np.round(region.min(),2)))
# Out:
# EASTERN region has the largest number of students  with a percentage of 16.67%
# GREATER ACCRA region has the least number of students  with a percentage of 2.87%

# %% [markdown]
# ### We are going to extract the gender and the first names of students as new columns

# %%
# If the name ends with (Miss) put 'F' else if its (Mr) put 'M'
df['sex'] = (df['Full Name'].str[-6:].str.strip()).apply(lambda x : 'M' if '(Mr.)' in x else 'F')
# We divide split the full name by '(' then we take the first split
df['Full Name'] = df['Full Name'].str.split('(').str[0]
# This code also take the first name of every name 
df['first_name'] = df['Full Name'].str.split(',').str[1].str.split(' ').str[-2]

# %% [markdown]
# ## Visualization of the Gender in percentage

# %%
plt.figure()
male,female = (df['sex']).value_counts().items()
plt.pie(np.array([male[1],female[1]]),labels=['Male','Female'],autopct='%1.2f%%',shadow=True,startangle=90,radius=1);
print('This shows the percentage of females and males selected')
# Out:
# <img src="data:image/png;base64,..." width="640">
# This shows the percentage of females and males selected

# %%
# Now lets check 15 randomly selected entries
df.sample(15)
# Out:
#                         Full Name  \
# 208            OBUOBISAH, DENNIS
# 608       BEKOE, THEOPHILUS KOJO
# 1370       KUNAKI, BLESS RAYMOND
# 402               SUKA, PATIENCE
# 940                ABIWU, GIDEON
# 11                OWUSU, DOUGLAS
# 331               ASIMIDU, ALILA
# 1495  ACKAAH-BOATENG, EMMANUELLA
# 1265      HARLLEY, KPEKA ANTHONY
# 438               ADDAE, REBECCA
# 526                NYARKO, GRACE
# 31       OWUSU, ANTWI EMMANUELLA
# 425             ABDALLAH, SALIFU
# 1183           GAYOMEH, EMMANUEL
# 513              NANTWI, JUSTICE
#
#                                               Programme  \
# 208                           BSC. DEVELOPMENT PLANNING
# 608                               BA. POLITICAL STUDIES
# 1370                                        BA. HISTORY
# 402                               BA. RELIGIOUS STUDIES
# 940   BSC. BUSINESS ADMINISTRATION (ACCOUNTING/BANKI...
# 11                            BA. COMMUNICATION STUDIES
# 331                                 BSC. FASHION DESIGN
# 1495                   BSC. FOOD SCIENCE AND TECHNOLOGY
# 1265                     BSC. HUMAN SETTLEMENT PLANNING
# 438                                        BSC. NURSING
# 526                                         BA. HISTORY
# 31                                      BA. SOCIAL WORK
# 425                                         BA. HISTORY
# 1183  BSC. BUSINESS ADMINISTRATION (MARKETING/INTERN...
# 513                            BA. COMMUNICATION DESIGN
#
#                               School       Region sex  first_name
# 208       ST. JEROME SNR HIGH SCHOOL      ASHANTI   M      DENNIS
# 608    KWEGYIR AGGREY SNR. HIGH TECH      CENTRAL   M        KOJO
# 1370     WOVENU SNR HIGH/TECH SCHOOL        VOLTA   M     RAYMOND
# 402         NKORAMAN SNR HIGH SCHOOL  BRONG AHAFO   F    PATIENCE
# 940     YILO KROBO SNR HIGH/COMM SCH      EASTERN   M      GIDEON
# 11        ADANWOMASE SNR HIGH SCHOOL      ASHANTI   M     DOUGLAS
# 331             JEMA SNR HIGH SCHOOL  BRONG AHAFO   F       ALILA
# 1495    SEFWI BEKWAI SNR HIGH SCHOOL      WESTERN   F  EMMANUELLA
# 1265   KETA BUSINESS SNR HIGH SCHOOL        VOLTA   M     ANTHONY
# 438          SUMAMAN SNR HIGH SCHOOL  BRONG AHAFO   F     REBECCA
# 526   BESEASE SNR. HIGH/COMM. SCHOOL      CENTRAL   F       GRACE
# 31               AGOGO STATE COLLEGE      ASHANTI   F  EMMANUELLA
# 425            PRANG SNR HIGH SCHOOL  BRONG AHAFO   M      SALIFU
# 1183     ABUTIA SNR HIGH/TECH SCHOOL        VOLTA   M    EMMANUEL
# 513   ASSIN NORTH SNR. HIGH/TECH SCH      CENTRAL   M     JUSTICE

# %%
df.columns
# Out:
# Index(['Full Name', 'Programme', 'School', 'Region', 'sex', 'first_name'], dtype='object')

# %%
Region = df["Region"]
Region.head()
# Out:
# 0    ASHANTI
# 1    ASHANTI
# 2    ASHANTI
# 3    ASHANTI
# 4    ASHANTI
# Name: Region, dtype: object

# %%
sex = df["sex"]
sex.head()
# Out:
# 0    M
# 1    F
# 2    F
# 3    M
# 4    M
# Name: sex, dtype: object

# %%
df=df.groupby(['sex','Region']).size()
df=df.unstack()
df.plot(kind='bar')
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:xlabel='sex'>
